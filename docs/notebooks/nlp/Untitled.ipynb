# %%
pip install bark
# Out:
# Collecting bark
#   Downloading bark-0.1.5-py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 35.5 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting boto3 (from bark)
#   Obtaining dependency information for boto3 from https://files.pythonhosted.org/packages/17/a4/e161e777d445a5b1029eff4c4272896410d7dac55e17f2889bd9a3517eed/boto3-1.28.78-py3-none-any.whl.metadata
#   Downloading boto3-1.28.78-py3-none-any.whl.metadata (6.7 kB)
# Collecting encodec (from bark)
#   Downloading encodec-0.1.1.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 96.2 MB/s eta 0:00:000m eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting funcy (from bark)
#   Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: huggingface-hub>=0.14.1 in /home/asif/anaconda3/lib/python3.11/site-packages (from bark) (0.17.3)
# Requirement already satisfied: numpy in /home/asif/anaconda3/lib/python3.11/site-packages (from bark) (1.24.4)
# Requirement already satisfied: scipy in /home/asif/.local/lib/python3.11/site-packages (from bark) (1.11.2)
# Requirement already satisfied: tokenizers in /home/asif/anaconda3/lib/python3.11/site-packages (from bark) (0.13.3)
# Requirement already satisfied: torch in /home/asif/anaconda3/lib/python3.11/site-packages (from bark) (2.0.1)
# Requirement already satisfied: tqdm in /home/asif/anaconda3/lib/python3.11/site-packages (from bark) (4.65.2)
# Requirement already satisfied: transformers in /home/asif/anaconda3/lib/python3.11/site-packages (from bark) (4.31.0)
# Requirement already satisfied: filelock in /home/asif/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.14.1->bark) (3.9.0)
# Requirement already satisfied: fsspec in /home/asif/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.14.1->bark) (2023.6.0)
# Requirement already satisfied: requests in /home/asif/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.14.1->bark) (2.28.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/asif/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.14.1->bark) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/asif/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.14.1->bark) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /home/asif/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.14.1->bark) (23.0)
# Collecting botocore<1.32.0,>=1.31.78 (from boto3->bark)
#   Obtaining dependency information for botocore<1.32.0,>=1.31.78 from https://files.pythonhosted.org/packages/64/93/d472917cc8000157d1220f18edf175e06b7f1ac92970e7cdb719d4405b5a/botocore-1.31.78-py3-none-any.whl.metadata
#   Downloading botocore-1.31.78-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/asif/anaconda3/lib/python3.11/site-packages (from boto3->bark) (0.10.0)
# Collecting s3transfer<0.8.0,>=0.7.0 (from boto3->bark)
#   Obtaining dependency information for s3transfer<0.8.0,>=0.7.0 from https://files.pythonhosted.org/packages/5a/4b/fec9ce18f8874a96c5061422625ba86c3ee1e6587ccd92ff9f5bf7bd91b2/s3transfer-0.7.0-py3-none-any.whl.metadata
#   Downloading s3transfer-0.7.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: torchaudio in /home/asif/anaconda3/lib/python3.11/site-packages (from encodec->bark) (2.0.2+cu118)
# Requirement already satisfied: einops in /home/asif/anaconda3/lib/python3.11/site-packages (from encodec->bark) (0.6.1)
# Requirement already satisfied: sympy in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (1.11.1)
# Requirement already satisfied: networkx in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (3.1)
# Requirement already satisfied: jinja2 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch->bark) (2.0.0)
# Requirement already satisfied: setuptools in /home/asif/anaconda3/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->bark) (60.2.0)
# Requirement already satisfied: wheel in /home/asif/anaconda3/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->bark) (0.41.2)
# Requirement already satisfied: cmake in /home/asif/anaconda3/lib/python3.11/site-packages (from triton==2.0.0->torch->bark) (3.27.7)
# Requirement already satisfied: lit in /home/asif/anaconda3/lib/python3.11/site-packages (from triton==2.0.0->torch->bark) (17.0.4)
# Requirement already satisfied: regex!=2019.12.17 in /home/asif/anaconda3/lib/python3.11/site-packages (from transformers->bark) (2022.7.9)
# Requirement already satisfied: safetensors>=0.3.1 in /home/asif/anaconda3/lib/python3.11/site-packages (from transformers->bark) (0.3.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/asif/anaconda3/lib/python3.11/site-packages (from botocore<1.32.0,>=1.31.78->boto3->bark) (2.8.2)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /home/asif/anaconda3/lib/python3.11/site-packages (from botocore<1.32.0,>=1.31.78->boto3->bark) (1.26.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/asif/anaconda3/lib/python3.11/site-packages (from jinja2->torch->bark) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/asif/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.14.1->bark) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/asif/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.14.1->bark) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/asif/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.14.1->bark) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /home/asif/anaconda3/lib/python3.11/site-packages (from sympy->torch->bark) (1.3.0)
# Requirement already satisfied: six>=1.5 in /home/asif/anaconda3/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.32.0,>=1.31.78->boto3->bark) (1.16.0)
# Downloading boto3-1.28.78-py3-none-any.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 96.5 MB/s eta 0:00:00
# Downloading botocore-1.31.78-py3-none-any.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 94.5 MB/s eta 0:00:000m eta 0:00:01:01:01
# Downloading s3transfer-0.7.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 35.5 MB/s eta 0:00:00
# Building wheels for collected packages: encodec
#   Building wheel for encodec (setup.py) ... done
#   Created wheel for encodec: filename=encodec-0.1.1-py3-none-any.whl size=45779 sha256=45e4e334f34ee6f12fec4ca77ba75d7195d09486145739b1eefa54baedeae611
#   Stored in directory: /home/asif/.cache/pip/wheels/b4/a4/88/480018a664e58ca7ce6708759193ee51b017b3b72aa3df8a85
# Successfully built encodec
# Installing collected packages: funcy, botocore, s3transfer, boto3, encodec, bark
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.29.76
#     Uninstalling botocore-1.29.76:
#       Successfully uninstalled botocore-1.29.76
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.5.0 requires botocore<1.29.77,>=1.29.76, but you have botocore 1.31.78 which is incompatible.
# Successfully installed bark-0.1.5 boto3-1.28.78 botocore-1.31.78 encodec-0.1.1 funcy-2.0 s3transfer-0.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from bark import SAMPLE_RATE, generate_audio, preload_models
from scipy.io.wavfile import write as write_wav
from IPython.display import Audio

# download and load all models
preload_models()

# generate audio from text
text_prompt = """
     Hello, my name is Suno. And, uh — and I like pizza. [laughs] 
     But I also have other interests such as playing tic tac toe.
"""
audio_array = generate_audio(text_prompt)

# save audio to disk
write_wav("bark_generation.wav", SAMPLE_RATE, audio_array)
  
# play text in notebook
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# /home/asif/anaconda3/lib/python3.11/site-packages/torch/cuda/__init__.py:138: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# /home/asif/anaconda3/lib/python3.11/site-packages/torch/cuda/__init__.py:611: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# No GPU being used. Careful, inference might be very slow!
# Downloading text_2.pt:   0%|          | 0.00/5.35G [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading coarse_2.pt:   0%|          | 0.00/3.93G [00:00<?, ?B/s]
# Downloading fine_2.pt:   0%|          | 0.00/3.74G [00:00<?, ?B/s]
# /home/asif/anaconda3/lib/python3.11/site-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Downloading: "https://dl.fbaipublicfiles.com/encodec/v0/encodec_24khz-d7cc33bc.th" to /home/asif/.cache/torch/hub/checkpoints/encodec_24khz-d7cc33bc.th
# 100%|████████████████████████████████████████████████████████████████████████| 88.9M/88.9M [00:00<00:00, 107MB/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 100/100 [00:26<00:00,  3.81it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 36/36 [01:42<00:00,  2.85s/it]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pip install torch torchaudio --upgrade
# Out:
# Requirement already satisfied: torch in /home/asif/anaconda3/lib/python3.11/site-packages (2.0.1)
# Collecting torch
#   Obtaining dependency information for torch from https://files.pythonhosted.org/packages/5b/13/fcabc86948f9e89b62a538670720f8589d63f93d3f4f3d172236a98e70f8/torch-2.1.0-cp311-cp311-manylinux1_x86_64.whl.metadata
#   Using cached torch-2.1.0-cp311-cp311-manylinux1_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: torchaudio in /home/asif/anaconda3/lib/python3.11/site-packages (2.0.2+cu118)
# Collecting torchaudio
#   Obtaining dependency information for torchaudio from https://files.pythonhosted.org/packages/8e/fb/32bebfa0aea36a2ee8f9cfab2ac023176a438163638587665616f13004d2/torchaudio-2.1.0-cp311-cp311-manylinux1_x86_64.whl.metadata
#   Using cached torchaudio-2.1.0-cp311-cp311-manylinux1_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: filelock in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/asif/anaconda3/lib/python3.11/site-packages (from torch) (12.1.105)
# Collecting triton==2.1.0 (from torch)
#   Obtaining dependency information for triton==2.1.0 from https://files.pythonhosted.org/packages/5c/c1/54fffb2eb13d293d9a429fead3646752ea190de0229bcf3d591ba2481263/triton-2.1.0-0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Using cached triton-2.1.0-0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/asif/anaconda3/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.3.52)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/asif/anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /home/asif/anaconda3/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Using cached torch-2.1.0-cp311-cp311-manylinux1_x86_64.whl (670.2 MB)
# Using cached triton-2.1.0-0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
# Using cached torchaudio-2.1.0-cp311-cp311-manylinux1_x86_64.whl (3.3 MB)
# Installing collected packages: triton, torch, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 2.0.0
#     Uninstalling triton-2.0.0:
#       Successfully uninstalled triton-2.0.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1
#     Uninstalling torch-2.0.1:
#       Successfully uninstalled torch-2.0.1
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.0.2+cu118
#     Uninstalling torchaudio-2.0.2+cu118:
#       Successfully uninstalled torchaudio-2.0.2+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.15.2 requires torch==2.0.1, but you have torch 2.1.0 which is incompatible.
# xformers 0.0.21 requires torch==2.0.1, but you have torch 2.1.0 which is incompatible.
# llava 1.1.3 requires torch==2.0.1, but you have torch 2.1.0 which is incompatible.
# spacy-transformers 1.2.5 requires transformers<4.31.0,>=3.4.0, but you have transformers 4.31.0 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 2.1.0 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 2.1.0 which is incompatible.
# Successfully installed torch-2.1.0 torchaudio-2.1.0 triton-2.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install git+https://github.com/huggingface/transformers.git
# Out:
# Collecting git+https://github.com/huggingface/transformers.git
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-yelhv1qu
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-yelhv1qu
#   Resolved https://github.com/huggingface/transformers.git to commit cc3e4781854a52cf090ffde28d884a527dab6708
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /home/asif/anaconda3/lib/python3.11/site-packages (from transformers==4.36.0.dev0) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/asif/anaconda3/lib/python3.11/site-packages (from transformers==4.36.0.dev0) (0.17.3)
# Requirement already satisfied: numpy>=1.17 in /home/asif/anaconda3/lib/python3.11/site-packages (from transformers==4.36.0.dev0) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /home/asif/anaconda3/lib/python3.11/site-packages (from transformers==4.36.0.dev0) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/asif/anaconda3/lib/python3.11/site-packages (from transformers==4.36.0.dev0) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/asif/anaconda3/lib/python3.11/site-packages (from transformers==4.36.0.dev0) (2022.7.9)
# Requirement already satisfied: requests in /home/asif/anaconda3/lib/python3.11/site-packages (from transformers==4.36.0.dev0) (2.28.2)
# Collecting tokenizers<0.15,>=0.14 (from transformers==4.36.0.dev0)
#   Downloading tokenizers-0.14.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.3.1 in /home/asif/anaconda3/lib/python3.11/site-packages (from transformers==4.36.0.dev0) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /home/asif/anaconda3/lib/python3.11/site-packages (from transformers==4.36.0.dev0) (4.65.2)
# Requirement already satisfied: fsspec in /home/asif/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.36.0.dev0) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/asif/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.36.0.dev0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/asif/anaconda3/lib/python3.11/site-packages (from requests->transformers==4.36.0.dev0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/asif/anaconda3/lib/python3.11/site-packages (from requests->transformers==4.36.0.dev0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/asif/anaconda3/lib/python3.11/site-packages (from requests->transformers==4.36.0.dev0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /home/asif/anaconda3/lib/python3.11/site-packages (from requests->transformers==4.36.0.dev0) (2023.7.22)
# Downloading tokenizers-0.14.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 47.5 MB/s eta 0:00:00m eta 0:00:010:01
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.36.0.dev0-py3-none-any.whl size=7923012 sha256=7ee493eceb5058529dc5ff58733eccd57b5e717f8080fba2533979535dd332ab
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3j5shkzo/wheels/32/4b/78/f195c684dd3a9ed21f3b39fe8f85b48df7918581b6437be143
# Successfully built transformers
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.3
#     Uninstalling tokenizers-0.13.3:
#       Successfully uninstalled tokenizers-0.13.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.31.0
#     Uninstalling transformers-4.31.0:
#       Successfully uninstalled transformers-4.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llava 1.1.3 requires tokenizers<0.14,>=0.12.1, but you have tokenizers 0.14.1 which is incompatible.
# llava 1.1.3 requires torch==2.0.1, but you have torch 2.1.0 which is incompatible.
# llava 1.1.3 requires transformers==4.31.0, but you have transformers 4.36.0.dev0 which is incompatible.
# spacy-transformers 1.2.5 requires transformers<4.31.0,>=3.4.0, but you have transformers 4.36.0.dev0 which is incompatible.
# chromadb 0.4.7 requires bcrypt>=4.0.1, but you have bcrypt 3.2.2 which is incompatible.
# Successfully installed tokenizers-0.14.1 transformers-4.36.0.dev0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pip --upgrade
# Out:
# Requirement already satisfied: pip in /home/asif/anaconda3/lib/python3.11/site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/47/6a/453160888fab7c6a432a6e25f8afe6256d0d9f2cbd25971021da6491d899/pip-23.3.1-py3-none-any.whl.metadata
#   Using cached pip-23.3.1-py3-none-any.whl.metadata (3.5 kB)
# Using cached pip-23.3.1-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.2.1
#     Uninstalling pip-23.2.1:
#       Successfully uninstalled pip-23.2.1
# Successfully installed pip-23.3.1
# Note: you may need to restart the kernel to use updated packages.
